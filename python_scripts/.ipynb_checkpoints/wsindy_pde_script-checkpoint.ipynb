# %% [markdown]
# # **WSINDy for PDEs: Examples**
#
# - Based on the [JCP paper by **D. A. Messenger**, **D. M. Bortz** (2021)](https://www.sciencedirect.com/science/article/pii/S0021999121004204).
# - See the authors' original [MatLab code repository](https://github.com/MathBioCU/WSINDy_PDE).
#
# Seth Minor, 2025
#
# ---
#
# This notebook illustrates the Weak SINDy algorithm being applied to various spatiotemporal systems:
# - the $(1+1)$-dimensional Kuramoto Sivashinsky equation
# - the $(2+1)$-dimensional Swift Hohenberg equation
# - the $(3+1)$-dimensional MHD equations

# %%
import torch
import scipy
import numpy as np
import itertools
import symengine as sp

import torch.linalg as la
from scipy.signal import convolve
from scipy.special import factorial
import scipy.io as sio
import matplotlib.pyplot as plt
from tqdm import tqdm

import os
import sys
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir+'/libs/pywsindy_base')
file_path = parent_dir+'/libs/wsindy_obj_base/pde_data'

from wsindy_smdm import *
from helper_fcns import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## **KURAMOTO SIVASHINKSY**

# %% [markdown]
# In this example, we use data from a numerical solution of the $(1+1)$-dimensional Kuramoto Sivashinsky equation: \begin{align*}
# u_t = -\frac{1}{2}\left(u^2\right)_{x} - u_{xx} - u_{xxxx},
# \quad \text{for} \quad
# \begin{cases}
# x \in [0, \, 32\pi],
# \\
# \, t \in [0, \, 150],
# \end{cases}
# \end{align*} using periodic boundary conditions. See the `KS.txt` file (1.3 MB) located [here](https://github.com/SethMinor/PyWSINDy-for-PDEs/blob/main/Datasets/KS.txt). These data were sourced from [this GitHub repository](https://github.com/MathBioCU/WSINDy_PDE/blob/master/datasets/KS.mat).

# %%
# load data, format with pytorch

dtype = torch.float64
data_path = file_path + '/KS.mat'
mat_contents = sio.loadmat(data_path)

U = mat_contents['U_exact'][0][0]
U = torch.tensor(U,dtype=dtype)
X = mat_contents['xs'][0]
X = [torch.tensor(grid.flatten(),dtype=dtype) for grid in X]

# %%
# add noise

noise = 0.5
if noise != 0:
  U = add_noise(U, noise)

# %%
print(f"Imported tensor with shape {U.numpy().shape}")

# Plot the data
fig,ax = plt.subplots(1,2,figsize=(7,2.5))

IC = U[:,1]
ax[0].plot(X[0], U[:,0])
ax[0].set_title('Initial Condition')
ax[0].set_xlabel('$x$')
ax[0].set_ylabel('$u(x,0)$')
ax[0].grid(True)

Xx,Tt = torch.meshgrid(*X, indexing='ij')
ax[1].pcolormesh(Tt, Xx, U)
ax[1].set_title('Evolution')
ax[1].set_xlabel('$t$')
ax[1].set_ylabel('$x$')

fig.tight_layout()
plt.show()
# Out:
# Imported tensor with shape (256, 301)

# %%
# set LHS and library 

lhs_tag = [1,0,1]

# Derivatives for test fcns
alpha = [lhs_tag[1:]] + get_tags(range(5),[],2,boolT = lambda tag : tag[1] == 0)

# Powers for homogeneous fcns
beta = get_tags(range(3),[],1)

model = WSINDy(U, alpha, beta, X)

# %%
# CREATE LIBRARY

# Create standard library terms
[G,powers,derivs,rhs_names] = model.create_default_library()

# Add a funky non-homogeneous term, e.g., D^i cos(u)
i = 1
kernel = [model.axes[d][i,:] for d in range(U.ndim)]
yxyt = np.prod(model.yx + [model.yt])
cos_term = compute_weak_trig(U, kernel, model.spacing, freq=1., phase=0., yxyt=yxyt)

G.append(cos_term[model.conv_mask])
powers.append([0])
derivs.append(i)
rhs_names.append(r'\cos(u)' + model.derivative_names[i])

del i, yxyt, kernel, cos_term
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 115.57it/s]

# %%
# Display the library in LaTeX
from IPython.display import display, Math

lib_string = r'\Theta=' + r'\{' + r', \, '.join(rhs_names) + r'\}'
display(Math(lib_string))
# Out:
# $\displaystyle \Theta=\{(1), \, (u), \, (u^2), \, (u)_{x}, \, (u^2)_{x}, \, (u)_{xx}, \, (u^2)_{xx}, \, (u)_{xxx}, \, (u^2)_{xxx}, \, (u)_{xxxx}, \, (u^2)_{xxxx}, \, \cos(u)\}$

# %%
# Set lhs
lhs_name = 'u' + model.derivative_names[0]
model.build_lhs(lhs_name)

# Set library
model.set_library(G, powers, derivs, rhs_names)

# Find sparse weights
w = model.MSTLS()
model.print_report()
# Out:
# HYPER-PARAMETERS
# m = [19, 34]
# p = [11, 9]
# s = [5, 6]
# [yx, yt] = [0.808, 0.059]
# yu = 0.699
# Aux. scales = []
#
# LIBRARY
# Num. query points = 1716
# Num. terms = 12
# cond(G) = 7.533e+01
#
# RESULTS
# PDE: u_{t} = - 0.45(u^2)_{x} - 0.90(u)_{xx} - 0.91(u)_{xxxx}
# Nonzero terms = 3
# Rel. L2 error = 0.342
# R^2 = 0.883
# Lambda = 7.197e-02
# Loss = 0.292

# %%
pde = symbolic_pde(model.lhs_name, model.rhs_names, model.coeffs)
display(Math(pde))
# Out:
# $\displaystyle u_{t} = - 0.45(u^2)_{x} - 0.90(u)_{xx} - 0.91(u)_{xxxx}$

# %%
# Reset variables for next example
del U, model, X, alpha, beta
del powers, derivs, lhs_name, rhs_names, lib_string
del G, w, noise, pde

# %% [markdown]
# ## **Navier Stokes**

# %% [markdown]
# Here we consider the 2D nondimensional N-S vorticity equation with Reynolds number $Re=100$
# \begin{align*}
# \partial_t \omega = -\partial_x(u\omega) -\partial_y(v \omega) + \frac{1}{100}(\partial_{xx}\omega+ \partial_{yy}\omega)
# \end{align*}

# %%
# load data, format with pytorch

dtype = torch.float64
data_path = file_path + '/Nav_Stokes.mat'
mat_contents = sio.loadmat(data_path)

U, V, W = mat_contents['U_exact'][0]
U, V, W = [torch.tensor(Z,dtype=dtype) for Z in [U,V,W]]

X = mat_contents['xs'][0]
X = [torch.tensor(grid.flatten(),dtype=dtype) for grid in X]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/envs/pytorch_amd/lib/python3.11/site-packages/scipy/io/matlab/_mio.py:39, in _open_file(file_like, appendmat, mode)
#      38 try:
# ---> 39     return open(file_like, mode), True
#      40 except OSError as e:
#      41     # Probably "not found"
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/danielmessenger/repos/WSciML-SIAMWorkshop2026/libs/wsindy_obj_base/pde_data/Nav_Stokes.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 5
#       1 # load data, format with pytorch
#       2
#       3 dtype = torch.float64
#       4 data_path = file_path + '/Nav_Stokes.mat'
# ----> 5 mat_contents = sio.loadmat(data_path)
#       6
#       7 U, V, W = mat_contents['U_exact'][0]
#       8 U, V, W = [torch.tensor(Z,dtype=dtype) for Z in [U,V,W]]
#
# File ~/anaconda3/envs/pytorch_amd/lib/python3.11/site-packages/scipy/io/matlab/_mio.py:234, in loadmat(file_name, mdict, appendmat, spmatrix, **kwargs)
#      88 """
#      89 Load MATLAB file.
#      90
#    (...)    231     3.14159265+3.14159265j])
#     232 """
#     233 variable_names = kwargs.pop('variable_names', None)
# --> 234 with _open_file_context(file_name, appendmat) as f:
#     235     MR, _ = mat_reader_factory(f, **kwargs)
#     236     matfile_dict = MR.get_variables(variable_names)
#
# File ~/anaconda3/envs/pytorch_amd/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/anaconda3/envs/pytorch_amd/lib/python3.11/site-packages/scipy/io/matlab/_mio.py:17, in _open_file_context(file_like, appendmat, mode)
#      15 @contextmanager
#      16 def _open_file_context(file_like, appendmat, mode='rb'):
# ---> 17     f, opened = _open_file(file_like, appendmat, mode)
#      18     try:
#      19         yield f
#
# File ~/anaconda3/envs/pytorch_amd/lib/python3.11/site-packages/scipy/io/matlab/_mio.py:45, in _open_file(file_like, appendmat, mode)
#      43     if appendmat and not file_like.endswith('.mat'):
#      44         file_like += '.mat'
# ---> 45     return open(file_like, mode), True
#      46 else:
#      47     raise OSError(
#      48         'Reader needs file name or open file-like object'
#      49     ) from e
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/danielmessenger/repos/WSciML-SIAMWorkshop2026/libs/wsindy_obj_base/pde_data/Nav_Stokes.mat'

# %%
# add noise

noise = 0.2
if noise != 0:
  U, V, W = [add_noise(Z, noise) for Z in [U,V,W]]

# %%
# print(f"Imported tensor with shape {U.numpy().shape}")

# # Plot the data
# fig,ax = plt.subplots(1,2,figsize=(7,2.5))

# IC = U[:,1]
# ax[0].plot(X[0], U[:,0])
# ax[0].set_title('Initial Condition')
# ax[0].set_xlabel('$x$')
# ax[0].set_ylabel('$u(x,0)$')
# ax[0].grid(True)

# Xx,Tt = torch.meshgrid(*X, indexing='ij')
# ax[1].pcolormesh(Tt, Xx, U)
# ax[1].set_title('Evolution')
# ax[1].set_xlabel('$t$')
# ax[1].set_ylabel('$x$')

# fig.tight_layout()
# plt.show()

# %%
# set library

lhs_tag = [0,0,1,0,0,1]

# Derivatives for test fcns
alpha = [lhs_tag[3:]] + get_tags(range(3),[],3, boolT=lambda tag: (tag[-1]==0) and (bool(tag[0]) ^ bool(tag[1])))

# Powers for homogeneous fcns
beta =  get_tags(range(4),[],3, boolT = lambda tag: tag[0]>0)

model = WSINDy(W, alpha, beta, X, V=[U,V], tau=1e-10, tau_hat=1)

# %%
# CREATE LIBRARY

# Create standard library terms
[G,powers,derivs,rhs_names] = model.create_default_library()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:24<00:00,  6.01s/it]

# %%
# Display the library in LaTeX
from IPython.display import display, Math

lib_string = r'\Theta=' + r'\{' + r', \, '.join(rhs_names) + r'\}'
display(Math(lib_string))
# Out:
# $\displaystyle \Theta=\{(u)_{x}, \, (u v2)_{x}, \, (u v1)_{x}, \, (u^2)_{x}, \, (u v2^2)_{x}, \, (u v1 v2)_{x}, \, (u v1^2)_{x}, \, (u^2 v2)_{x}, \, (u^2 v1)_{x}, \, (u^3)_{x}, \, (u)_{y}, \, (u v2)_{y}, \, (u v1)_{y}, \, (u^2)_{y}, \, (u v2^2)_{y}, \, (u v1 v2)_{y}, \, (u v1^2)_{y}, \, (u^2 v2)_{y}, \, (u^2 v1)_{y}, \, (u^3)_{y}, \, (u)_{yy}, \, (u v2)_{yy}, \, (u v1)_{yy}, \, (u^2)_{yy}, \, (u v2^2)_{yy}, \, (u v1 v2)_{yy}, \, (u v1^2)_{yy}, \, (u^2 v2)_{yy}, \, (u^2 v1)_{yy}, \, (u^3)_{yy}, \, (u)_{xx}, \, (u v2)_{xx}, \, (u v1)_{xx}, \, (u^2)_{xx}, \, (u v2^2)_{xx}, \, (u v1 v2)_{xx}, \, (u v1^2)_{xx}, \, (u^2 v2)_{xx}, \, (u^2 v1)_{xx}, \, (u^3)_{xx}\}$

# %%
# Set lhs
lhs_name = 'u' + model.derivative_names[0]
model.build_lhs(lhs_name)

# Set library
model.set_library(G, powers, derivs, rhs_names)

# Find sparse weights
w = model.MSTLS()
model.print_report()
# Out:
# HYPER-PARAMETERS
# m = [37, 49, 11]
# p = [8, 8, 14]
# s = [6, 2, 4]
# [yx, yt] = [5.405, 4.082, 0.455]
# yu = 0.623
# Aux. scales = [0.947, 1.507]
#
# LIBRARY
# Num. query points = 49140
# Num. terms = 40
# cond(G) = 3.093e+02
#
# RESULTS
# PDE: u_{t} = - 1.00(u v1)_{x} - 1.00(u v2)_{y} + 0.01(u)_{yy} + 0.01(u)_{xx}
# Nonzero terms = 4
# Rel. L2 error = 0.011
# R^2 = 1.000
# Lambda = 3.556e-03
# Loss = 0.102

# %%
pde = symbolic_pde(model.lhs_name, model.rhs_names, model.coeffs)
display(Math(pde))
# Out:
# $\displaystyle u_{t} = - 1.00(u v1)_{x} - 1.00(u v2)_{y} + 0.01(u)_{yy} + 0.01(u)_{xx}$
